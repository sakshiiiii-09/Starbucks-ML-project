# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshiiiii-09/Starbucks-ML-project/blob/main/starbucks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/starbucks.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage                   242 non-null    object
#  2   Beverage_prep              242 non-null    object
#  3   Calories                   242 non-null    int64
#  4    Total Fat (g)             242 non-null    object
#  5   Trans Fat (g)              242 non-null    float64
#  6   Saturated Fat (g)          242 non-null    float64
#  7    Sodium (mg)               242 non-null    int64
#  8    Total Carbohydrates (g)   242 non-null    int64
#  9   Cholesterol (mg)           242 non-null    int64
#  10   Dietary Fibre (g)         242 non-null    int64
#  11   Sugars (g)                242 non-null    int64
#  12   Protein (g)               242 non-null    float64
# ...

# %%
df.shape
# Out:
# (242, 18)

# %%
df.isnull().sum()
# Out:
# Beverage_category            0
# Beverage                     0
# Beverage_prep                0
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                1
# dtype: int64

# %%
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Caffeine (mg)'] = pd.to_numeric(df['Caffeine (mg)'], errors='coerce')
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
median_caffeine = df['Caffeine (mg)'].median()
df['Caffeine (mg)'].fillna(median_caffeine, inplace=True)
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.isnull().sum()
# Out:
# Beverage_category            0
# Beverage                     0
# Beverage_prep                0
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage                   242 non-null    object
#  2   Beverage_prep              242 non-null    object
#  3   Calories                   242 non-null    int64
#  4    Total Fat (g)             242 non-null    object
#  5   Trans Fat (g)              242 non-null    float64
#  6   Saturated Fat (g)          242 non-null    float64
#  7    Sodium (mg)               242 non-null    int64
#  8    Total Carbohydrates (g)   242 non-null    int64
#  9   Cholesterol (mg)           242 non-null    int64
#  10   Dietary Fibre (g)         242 non-null    int64
#  11   Sugars (g)                242 non-null    int64
#  12   Protein (g)               242 non-null    float64
# ...

# %%
df[' Total Fat (g)'].astype(str).str.contains('[^0-9.]')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 237     True
# 238    False
# 239    False
# 240    False
# 241    False
# Name:  Total Fat (g), Length: 242, dtype: bool

# %%
df[' Total Fat (g)'].dtype
# Out:
# dtype('O')

# %%
df[' Total Fat (g)'] = pd.to_numeric(df[' Total Fat (g)'], errors='coerce')

# %%
df[' Total Fat (g)'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage                   242 non-null    object
#  2   Beverage_prep              242 non-null    object
#  3   Calories                   242 non-null    int64
#  4    Total Fat (g)             241 non-null    float64
#  5   Trans Fat (g)              242 non-null    float64
#  6   Saturated Fat (g)          242 non-null    float64
#  7    Sodium (mg)               242 non-null    int64
#  8    Total Carbohydrates (g)   242 non-null    int64
#  9   Cholesterol (mg)           242 non-null    int64
#  10   Dietary Fibre (g)         242 non-null    int64
#  11   Sugars (g)                242 non-null    int64
#  12   Protein (g)               242 non-null    float64
# ...

# %%
df.columns = df.columns.str.strip()

# %%
percent_columns = ['Vitamin A (% DV)']
for col in percent_columns:
  df[col] = df[col].str.rstrip('%').astype(float) / 100.0

# %%
percent_columns = ['Vitamin C (% DV)']
for col in percent_columns:
  df[col] = df[col].str.rstrip('%').astype(float) / 100.0

# %%
percent_columns = ['Calcium (% DV)']
for col in percent_columns:
  df[col] = df[col].str.rstrip('%').astype(float) / 100.0

# %%
percent_columns = ['Iron (% DV)']
for col in percent_columns:
  df[col] = df[col].str.rstrip('%').astype(float) / 100.0

# %%
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beverage_category        242 non-null    object
#  1   Beverage                 242 non-null    object
#  2   Beverage_prep            242 non-null    object
#  3   Calories                 242 non-null    int64
#  4   Total Fat (g)            241 non-null    float64
#  5   Trans Fat (g)            242 non-null    float64
#  6   Saturated Fat (g)        242 non-null    float64
#  7   Sodium (mg)              242 non-null    int64
#  8   Total Carbohydrates (g)  242 non-null    int64
#  9   Cholesterol (mg)         242 non-null    int64
#  10  Dietary Fibre (g)        242 non-null    int64
#  11  Sugars (g)               242 non-null    int64
#  12  Protein (g)              242 non-null    float64
#  13  Vitamin A (% DV)         242 non-null    float64
# ...

# %%
print(df.columns)
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        'Total Fat (g)', 'Trans Fat (g)', 'Saturated Fat (g)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Cholesterol (mg)', 'Dietary Fibre (g)',
#        'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)',
#        'Calcium (% DV)', 'Iron (% DV)', 'Caffeine (mg)'],
#       dtype='object')

# %%
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Beverage_category'] = label_encoder.fit_transform(df['Beverage_category'])
df['Beverage_prep'] = label_encoder.fit_transform(df['Beverage_prep'])
df['Beverage'] = label_encoder.fit_transform(df['Beverage'])
df
# Out:
#      Beverage_category  Beverage  Beverage_prep  Calories  Total Fat (g)  \
# 0                    1         1              4         3            0.1
# 1                    1         1              8         4            0.1
# 2                    1         1              2         5            0.1
# 3                    1         1             10         5            0.1
# 4                    0         3              5        70            0.1
# ..                 ...       ...            ...       ...            ...
# 237                  3        23              7       320            NaN
# 238                  3        30              9       170            0.1
# 239                  3        30             12       200            3.5
# 240                  3        30              7       180            1.5
# 241                  3        30              3       240            0.1
#
#      Trans Fat (g)  Saturated Fat (g)  Sodium (mg)  Total Carbohydrates (g)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beverage_category        242 non-null    int64
#  1   Beverage                 242 non-null    int64
#  2   Beverage_prep            242 non-null    int64
#  3   Calories                 242 non-null    int64
#  4   Total Fat (g)            241 non-null    float64
#  5   Trans Fat (g)            242 non-null    float64
#  6   Saturated Fat (g)        242 non-null    float64
#  7   Sodium (mg)              242 non-null    int64
#  8   Total Carbohydrates (g)  242 non-null    int64
#  9   Cholesterol (mg)         242 non-null    int64
#  10  Dietary Fibre (g)        242 non-null    int64
#  11  Sugars (g)               242 non-null    int64
#  12  Protein (g)              242 non-null    float64
#  13  Vitamin A (% DV)         242 non-null    float64
# ...

# %%
df
# Out:
#      Beverage_category  Beverage  Beverage_prep  Calories  Total Fat (g)  \
# 0                    1         1              4         3            0.1
# 1                    1         1              8         4            0.1
# 2                    1         1              2         5            0.1
# 3                    1         1             10         5            0.1
# 4                    0         3              5        70            0.1
# ..                 ...       ...            ...       ...            ...
# 237                  3        23              7       320            NaN
# 238                  3        30              9       170            0.1
# 239                  3        30             12       200            3.5
# 240                  3        30              7       180            1.5
# 241                  3        30              3       240            0.1
#
#      Trans Fat (g)  Saturated Fat (g)  Sodium (mg)  Total Carbohydrates (g)  \
# ...

# %%
df.isnull().sum()
# Out:
# Beverage_category          0
# Beverage                   0
# Beverage_prep              0
# Calories                   0
# Total Fat (g)              1
# Trans Fat (g)              0
# Saturated Fat (g)          0
# Sodium (mg)                0
# Total Carbohydrates (g)    0
# Cholesterol (mg)           0
# Dietary Fibre (g)          0
# Sugars (g)                 0
# Protein (g)                0
# Vitamin A (% DV)           0
# Vitamin C (% DV)           0
# Calcium (% DV)             0
# Iron (% DV)                0
# Caffeine (mg)              0
# dtype: int64

# %%
median_caffeine = df['Total Fat (g)'].median()
df['Total Fat (g)'].fillna(median_caffeine, inplace=True)
df
# Out:
#      Beverage_category  Beverage  Beverage_prep  Calories  Total Fat (g)  \
# 0                    1         1              4         3            0.1
# 1                    1         1              8         4            0.1
# 2                    1         1              2         5            0.1
# 3                    1         1             10         5            0.1
# 4                    0         3              5        70            0.1
# ..                 ...       ...            ...       ...            ...
# 237                  3        23              7       320            2.5
# 238                  3        30              9       170            0.1
# 239                  3        30             12       200            3.5
# 240                  3        30              7       180            1.5
# 241                  3        30              3       240            0.1
#
#      Trans Fat (g)  Saturated Fat (g)  Sodium (mg)  Total Carbohydrates (g)  \
# ...

# %%
df.isnull().sum()
# Out:
# Beverage_category          0
# Beverage                   0
# Beverage_prep              0
# Calories                   0
# Total Fat (g)              0
# Trans Fat (g)              0
# Saturated Fat (g)          0
# Sodium (mg)                0
# Total Carbohydrates (g)    0
# Cholesterol (mg)           0
# Dietary Fibre (g)          0
# Sugars (g)                 0
# Protein (g)                0
# Vitamin A (% DV)           0
# Vitamin C (% DV)           0
# Calcium (% DV)             0
# Iron (% DV)                0
# Caffeine (mg)              0
# dtype: int64

# %%
df['Beverage_category'].value_counts().plot(kind='bar')
plt.show()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Beverage_category'}>,
#         <Axes: title={'center': 'Beverage'}>,
#         <Axes: title={'center': 'Beverage_prep'}>,
#         <Axes: title={'center': 'Calories'}>],
#        [<Axes: title={'center': 'Total Fat (g)'}>,
#         <Axes: title={'center': 'Trans Fat (g)'}>,
#         <Axes: title={'center': 'Saturated Fat (g)'}>,
#         <Axes: title={'center': 'Sodium (mg)'}>],
#        [<Axes: title={'center': 'Total Carbohydrates (g)'}>,
#         <Axes: title={'center': 'Cholesterol (mg)'}>,
#         <Axes: title={'center': 'Dietary Fibre (g)'}>,
#         <Axes: title={'center': 'Sugars (g)'}>],
#        [<Axes: title={'center': 'Protein (g)'}>,
#         <Axes: title={'center': 'Vitamin A (% DV)'}>,
#         <Axes: title={'center': 'Vitamin C (% DV)'}>,
#         <Axes: title={'center': 'Calcium (% DV)'}>],
#        [<Axes: title={'center': 'Iron (% DV)'}>,
#         <Axes: title={'center': 'Caffeine (mg)'}>, <Axes: >, <Axes: >]],
# ...

# %%
sns.pairplot(df)

# %%
x = df.drop(columns=['Calories'])
y = df['Calories']

# %%
x
# Out:
#      Beverage_category  Beverage  Beverage_prep  Total Fat (g)  Trans Fat (g)  \
# 0                    1         1              4            0.1            0.0
# 1                    1         1              8            0.1            0.0
# 2                    1         1              2            0.1            0.0
# 3                    1         1             10            0.1            0.0
# 4                    0         3              5            0.1            0.1
# ..                 ...       ...            ...            ...            ...
# 237                  3        23              7            2.5            0.4
# 238                  3        30              9            0.1            0.1
# 239                  3        30             12            3.5            2.0
# 240                  3        30              7            1.5            0.2
# 241                  3        30              3            0.1            0.1
#
# ...

# %%
y
# Out:
# 0        3
# 1        4
# 2        5
# 3        5
# 4       70
#       ...
# 237    320
# 238    170
# 239    200
# 240    180
# 241    240
# Name: Calories, Length: 242, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.60623904, -0.98461775,  0.31293696, ..., -0.75511038,
#         -0.12992369,  0.17534394],
#        [-0.60623904,  0.12785882,  0.31293696, ..., -0.75511038,
#          0.25584973, -0.29906793],
#        [-1.26727936, -1.38915469, -0.69367692, ...,  1.30331198,
#         -0.70858383,  0.96603037],
#        ...,
#        [-0.60623904, -0.68121505,  1.5712043 , ..., -0.89233854,
#         -0.70858383, -0.29906793],
#        [ 0.71584158, -0.47894658,  1.31955083, ...,  1.98945277,
#          2.18471686, -0.93161708],
#        [ 0.05480127, -0.68121505,  0.81624389, ..., -0.75511038,
#         -0.70858383, -0.29906793]])

# %%
x_test
# Out:
# array([[ 1.12397692e+00,  8.50635450e-01,  8.11400582e-01,
#         -9.63491977e-01, -7.36279928e-01, -5.27504379e-01,
#         -6.20555671e-02, -5.09643573e-01, -1.85166766e-01,
#         -6.03138644e-01, -1.31539759e-01, -1.51316020e-01,
#          8.42749828e-02, -3.67166869e-01,  1.57834658e-02,
#         -5.39150683e-01, -2.77261506e-01],
#        [ 9.13231249e-02, -2.56834375e-01, -8.00435709e-01,
#         -9.99669070e-01, -8.03463758e-01, -5.27504379e-01,
#         -6.70200125e-01, -1.07107647e+00, -6.29930076e-01,
#         -6.03138644e-01, -5.02500807e-01, -9.57238299e-01,
#         -6.23634873e-01, -3.67166869e-01, -8.27914526e-01,
#         -5.39150683e-01,  8.99226506e-02],
#        [-1.62976654e+00, -1.16294605e+00,  2.74121818e-01,
#          5.92123039e-01, -4.67544610e-01, -5.27504379e-01,
#         -6.70200125e-01, -1.72783837e-01, -1.20812238e+00,
#         -2.36524958e-02, -1.29079303e+00,  4.53125690e-01,
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
independent_feature_names = df.columns.difference(['Caffeine (mg)'])
lm_coff=pd.Series(lm.coef_,index=independent_feature_names)
lm_coff
# Out:
# Beverage                   -0.089808
# Beverage_category           0.675129
# Beverage_prep               1.046605
# Calcium (% DV)             33.208094
# Calories                   -3.628588
# Cholesterol (mg)           -2.125890
# Dietary Fibre (g)          -0.233948
# Iron (% DV)                 0.869106
# Protein (g)                61.332293
# Saturated Fat (g)           2.924184
# Sodium (mg)                17.552206
# Sugars (g)                  8.159271
# Total Carbohydrates (g)     1.732590
# Total Fat (g)               2.216176
# Trans Fat (g)               7.931588
# Vitamin A (% DV)           -7.137585
# Vitamin C (% DV)            1.061980
# dtype: float64

# %%
lm_coff.plot(kind='bar')
# Out:
# <Axes: >

# %%
lm.score(x_train,y_train)
# Out:
# 0.9979714192628332

# %%
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([150.81613933,  99.27726204, 125.15281818, 198.52729288,
#         99.91332682, 345.08475594, 155.18404049, 135.72804815,
#        273.16081227, 258.10267319, 118.24960171,  60.94991738,
#        339.93473397, 423.74441647, 202.10646463, 112.04523083,
#        206.98417879, 203.26603786, 282.49671144, 184.9700753 ,
#        228.48293307, 101.08225433, 280.2169355 ,  79.45949795,
#        123.90599154,  11.61461455, 376.26035052, 236.50199492,
#         79.02874526, 165.53833566,   7.57352388, 402.43468249,
#        117.41057825, 136.75769468, 183.39873565, 289.06123771,
#        134.96351216, 277.65643327, 233.51873348, 189.34833456,
#         86.87761079, 174.84916522, 266.49230029, 115.70656493,
#        264.79402424, 319.80336577, 194.31541156, 163.55078791,
#        180.78401379])

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 257.7934237434619

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9716846993314967

# %%
from sklearn.linear_model import Ridge
rid=Ridge()
rid.fit(x_train,y_train)
# Out:
# Ridge()

# %%
independent_feature_names = df.columns.difference(['Caffeine (mg)'])
rid_coff=pd.Series(rid.coef_,index=independent_feature_names)
rid_coff
# Out:
# Beverage                   -0.131513
# Beverage_category           0.364703
# Beverage_prep               0.958560
# Calcium (% DV)             31.188718
# Calories                   -1.772377
# Cholesterol (mg)           -1.341477
# Dietary Fibre (g)          -1.247105
# Iron (% DV)                 0.648798
# Protein (g)                43.473656
# Saturated Fat (g)           4.959059
# Sodium (mg)                34.286897
# Sugars (g)                  9.029187
# Total Carbohydrates (g)     1.561547
# Total Fat (g)               2.527533
# Trans Fat (g)               8.260268
# Vitamin A (% DV)           -6.320034
# Vitamin C (% DV)            1.082737
# dtype: float64

# %%
rid_coff.plot(kind='bar')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import Lasso
la=Lasso()
la.fit(x_train,y_train)
# Out:
# Lasso()

# %%
independent_feature_names = df.columns.difference(['Caffeine (mg)'])
la_coff=pd.Series(la.coef_,index=independent_feature_names)
la_coff
# Out:
# Beverage                    0.000000
# Beverage_category           0.592318
# Beverage_prep               0.000000
# Calcium (% DV)             25.340557
# Calories                    0.000000
# Cholesterol (mg)            0.000000
# Dietary Fibre (g)           0.000000
# Iron (% DV)                 1.253792
# Protein (g)                68.361969
# Saturated Fat (g)           0.000000
# Sodium (mg)                 9.572515
# Sugars (g)                  7.399779
# Total Carbohydrates (g)     0.000000
# Total Fat (g)               2.792454
# Trans Fat (g)               9.826551
# Vitamin A (% DV)           -2.057378
# Vitamin C (% DV)            0.000000
# dtype: float64

# %%
la_coff.plot(kind='bar')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import ElasticNet
elnet=ElasticNet()
elnet.fit(x_train, y_train)
# Out:
# ElasticNet()

# %%
independent_feature_names = df.columns.difference(['Caffeine (mg)'])
elnet_coff=pd.Series(elnet.coef_,index=independent_feature_names)
elnet_coff
# Out:
# Beverage                    3.208095
# Beverage_category           3.371600
# Beverage_prep               2.000019
# Calcium (% DV)             12.006648
# Calories                    8.940266
# Cholesterol (mg)            2.147771
# Dietary Fibre (g)           2.079590
# Iron (% DV)                12.692994
# Protein (g)                26.199158
# Saturated Fat (g)           5.219991
# Sodium (mg)                25.961823
# Sugars (g)                  7.136242
# Total Carbohydrates (g)     1.869603
# Total Fat (g)               3.282996
# Trans Fat (g)               7.628633
# Vitamin A (% DV)            3.606040
# Vitamin C (% DV)            0.158207
# dtype: float64

# %%
elnet_coff.plot(kind='bar')
# Out:
# <Axes: >

# %%
rid_pred=rid.predict(x_test)
rid_pred
# Out:
# array([149.95061698, 100.51395008, 124.9066095 , 198.84129997,
#        100.20509903, 348.28391785, 155.6244473 , 136.0227139 ,
#        271.55132778, 254.72349055, 118.45117321,  61.84239937,
#        340.62799551, 426.17062032, 201.47737091, 112.65620525,
#        208.07111176, 205.40053226, 281.22810184, 185.42074489,
#        227.02333271, 100.0565447 , 279.43573638,  80.51952786,
#        124.20991578,  13.23204587, 376.9619501 , 233.90795557,
#         80.34428186, 166.6943608 ,   8.15503132, 402.64299512,
#        117.70192494, 136.94176383, 183.7765741 , 287.75004123,
#        135.60632103, 277.25626993, 233.44644845, 186.47549272,
#         87.77207806, 174.30970951, 265.99271194, 116.12067302,
#        262.1548416 , 318.04170286, 194.2959553 , 163.31873239,
#        180.96825431])

# %%
la_pred=la.predict(x_test)
la_pred
# Out:
# array([152.42844004, 101.941584  , 122.41549601, 201.85473451,
#         99.15389539, 342.20938025, 155.71540955, 138.02604871,
#        275.556119  , 247.8686175 , 120.16057138,  61.40920174,
#        337.86068935, 430.50752698, 201.9736803 , 112.86866679,
#        211.07697885, 203.0838564 , 280.38867566, 184.65518036,
#        230.9213094 , 102.93048038, 282.14664938,  79.96329652,
#        127.6387353 ,   9.87655939, 367.02435525, 236.66176524,
#         82.04895484, 166.26785537,   9.74332562, 405.18859663,
#        117.22203778, 135.70387856, 177.46409472, 289.11902382,
#        138.54382194, 278.83539179, 233.9361077 , 191.59819343,
#         92.25042521, 173.95027861, 263.61461785, 116.51398108,
#        256.29752393, 318.3515421 , 193.53526118, 160.34388518,
#        178.2362006 ])

# %%
elnet_pred=elnet.predict(x_test)
elnet_pred
# Out:
# array([158.58215241, 104.14950309, 129.02507968, 193.4933848 ,
#        113.33314445, 329.8572788 , 169.71234975, 147.56307068,
#        272.04100738, 251.33925673, 124.63006285,  72.69428501,
#        328.88540318, 424.03816521, 208.39108515, 130.94697643,
#        213.20157847, 211.37656906, 278.4071802 , 161.48641637,
#        218.33676688, 114.6083575 , 268.18404392,  90.2659317 ,
#        142.7816514 ,  30.79482038, 339.05993811, 226.57486421,
#         96.39861253, 158.74403725,  44.91352744, 384.27816517,
#        113.06215945, 147.54827824, 183.75998637, 268.32564451,
#        147.828159  , 266.75676588, 213.9768977 , 158.2432087 ,
#        113.73506247, 182.23666143, 249.11315119, 127.89445957,
#        243.31648829, 299.10765745, 192.29452772, 164.41892969,
#        187.37019767])

# %%
from sklearn import  metrics
metrics.mean_squared_error(y_test,rid_pred)
# Out:
# 263.7392448972245

# %%
metrics.r2_score(y_test,rid_pred)
# Out:
# 0.975835195562985

# %%
rid.score(x_test,y_test)
# Out:
# 0.975835195562985

# %%
metrics.mean_squared_error(y_test,la_pred)
# Out:
# 262.9075624571875

# %%
metrics.r2_score(y_test,la_pred)
# Out:
# 0.9759113975083005

# %%
la.score(x_test,y_test)
# Out:
# 0.9759113975083005

# %%
metrics.mean_squared_error(y_test,elnet_pred)
# Out:
# 720.4773155193247

# %%
metrics.r2_score(y_test,elnet_pred)
# Out:
# 0.9339870960894935

# %%
elnet.score(x_test,y_test)
# Out:
# 0.9339870960894935
